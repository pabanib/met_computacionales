# %%
# %load_ext rpy2.ipython

# %%
# %%R
# d <- c(6,5)
# print(d)
# Out:
# [1] 6 5

# %%
d = [5,6]
print(d)
# Out:
# [5, 6]

# %%
d = %R d
print(d)
# Out:
# [6. 5.]

# %%
d+[6]
d
# Out:
# array([6., 5.])
